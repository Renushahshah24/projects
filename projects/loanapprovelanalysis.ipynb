# %% [markdown]
# <h1>LOAN APPROVEL  </H1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4>Read CSV File </h4>

# %%
loan_df = pd.read_csv('c:\\Users\\HP\\Desktop\\projects\\loan_sanction_test.csv')

# %%
loan_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# <h4>Display first five row Header data from datafram </h4>

# %%
loan_df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %% [markdown]
# <h4>Display first five row Footer data from datafram </h4>

# %%
loan_df.tail(5)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 362             1.0         Urban
# 363             1.0         Urban
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %% [markdown]
# <h3> Cleaning Data</h3>

# %%
loan_df.drop('Loan_ID',axis=1,inplace=True)

# %%
loan_df['Dependents'] = loan_df['Dependents'].str.replace("+","")

# %%
loan_df['Dependents'] = loan_df['Dependents'].astype('Int64')

# %%
loan_df['Dependents'].dtype
# Out:
# Int64Dtype()

# %%
num_row = loan_df.shape[0]
num_column = loan_df.shape[1]
print(f"number of row is: {num_row}")
print(f"number of column is : {num_column}")
# Out:
# number of row is: 367
# number of column is : 11

# %% [markdown]
# <h3>Checking  Missing Values</h3>

# %%
loan_df.isnull().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
loan_df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# <h3> Drop missing values or handle them as needed:
#  </h3>

# %%
loan_df.dropna(axis=0, inplace=True)

# %%
loan_df.shape
# Out:
# (289, 11)

# %% [markdown]
# <h3> Checking Statistical</h3>

# %%
loan_df.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count       289.0       289.000000         289.000000  289.000000
# mean     0.802768      4637.352941        1528.262976  136.792388
# std      1.063533      4790.683934        2377.599209   59.699582
# min           0.0         0.000000           0.000000   28.000000
# 25%           0.0      2875.000000           0.000000  102.000000
# 50%           0.0      3833.000000         879.000000  126.000000
# 75%           2.0      5000.000000        2400.000000  158.000000
# max           3.0     72529.000000       24000.000000  460.000000
#
#        Loan_Amount_Term  Credit_History
# count        289.000000      289.000000
# mean         342.671280        0.840830
# std           65.655503        0.366469
# min            6.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %% [markdown]
# <h1> Task-2 Visualize Numeric Columns</h1>

# %%
# checking for alphabetic data in Numeric columns

loan_df[['Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']].applymap(np.isreal).all()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11260\434028179.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   loan_df[['Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']].applymap(np.isreal).all()
# Dependents           True
# ApplicantIncome      True
# CoapplicantIncome    True
# LoanAmount           True
# Loan_Amount_Term     True
# Credit_History       True
# dtype: bool

# %%
# creating list of numeric columns with year excluded
num_column = loan_df.select_dtypes(include=['float64','int64']).columns.to_list()[::]
num_column
# Out:
# ['Dependents',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %% [markdown]
# <h2> histograms graph </h2>

# %%
loan_df[num_column].hist(bins=20, figsize=(14, 10), edgecolor='Black')
plt.suptitle('Histograms of Numeric Columns')
#plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Box plot </h2>

# %%
plt.figure(figsize=(14, 8))
for i, col in enumerate(num_column):
    plt.subplot(2, (len(num_column)+1)//2, i+1)
    sns.boxplot(y=loan_df[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Bar chart </h2>

# %%
categorical_cols = ['Gender','Married','Dependents','Education','Self_Employed','property_area' ]

# %%
categorical_cols = loan_df.select_dtypes(include=['object']).columns.to_list()[::]
categorical_cols
# Out:
# ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area']

# %%
categorical_cols = loan_df.select_dtypes(include='object').columns
for col in categorical_cols:
    plt.figure(figsize=(5,4))
    sns.countplot(data=loan_df, x=col, order=loan_df[col].value_counts().index,color='purple',width=0.5)
    plt.title(f'Bar Chart of {col}')
    plt.xticks(rotation=80)
    plt.show()

# %% [markdown]
# <h2> Pie plot </h2>

# %%
colors = ["red","yellow"]
for col in categorical_cols:
    plt.figure(figsize=(3,8))
    loan_df[col].value_counts().plot.pie(autopct='%.2f%%', startangle=90, shadow=True,color='colors')
    plt.title(f'Pie Chart of {col}',fontdict={'weight':'bold'})
    plt.tight_layout()
    plt.legend(bbox_to_anchor=(1.4,1.1))
    plt.show()

# %% [markdown]
# <h2>: Interpretation Tips</h2>
# <h3>
# Histograms: Skewed income/loan values? Might need log transformation.
#
# Box Plots: Spot extreme values in income or loan amount.
#
# Bar Charts: Identify imbalances in categories like Gender, Education, etc.
#
# Pie Charts: Quick glance at category proportions, e.g., approval rates.
# </h3>

# %% [markdown]
# <h2>2.2 Bivariate Analysis </h2>

# %% [markdown]
# <h2> Scatter plot</h2>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(loan_df, x='ApplicantIncome', y='LoanAmount',alpha= 0.5,marker='*',color='purple')
plt.xlabel('Applicant Income')
plt.ylabel('Loan Amount')
plt.title('Applicant Income and Loan Amount')
plt.show()

# %% [markdown]
# <h2> Pair plot </h2>

# %%
column1 = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']
sns.pairplot(loan_df[column1 + ['Dependents']],hue='Dependents' ,palette='husl')
plt.suptitle('Pairwise Relationships of Numeric Variables', y=1.02)
plt.show()

# %% [markdown]
# <h2> Box plot </h2>

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(data=loan_df, x='Education', y='ApplicantIncome', hue='Education')
plt.title('Applicant Income by Education')
plt.show()

# %% [markdown]
# <h2> Violinplot </h2>

# %%
#colors = ("yellow","black","red")

plt.figure(figsize=(8, 6))
sns.violinplot(data=loan_df, x='Property_Area', y='LoanAmount', hue='Education', split=True)
plt.title('Loan Amount Distribution by Property Area & Education')
plt.show()

# %% [markdown]
# <h2>2.3 Multivariate Analysis</h2>

# %%
colors = ("yellow","pink","red","purple","green","orange")
corr_matrix = loan_df.select_dtypes(include='number').corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, color=colors, fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# <h2> Interpretation</h2>
# <h3>
# Values range from -1 to 1
#
# Closer to 1: Strong positive correlation
#
# Closer to -1: Strong negative correlation
#
# Closer to 0: No linear correlation
# </h3>

# %% [markdown]
# <h2>  Plot stacked bar chart </h2>

# %%
column = loan_df(('Property_Area'),('Education'))
plt.plot(column.x,column.y,kind='bar', stacked=True, figsize=(8,6), colormap='viridis')
plt.title('Education by Property Area')
plt.xlabel('Property Area')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.title('Education')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 column = loan_df(('Property_Area'),('Education'))
#       2 plt.plot(column.x,column.y,kind='bar', stacked=True, figsize=(8,6), colormap='viridis')
#       3 plt.title('Education by Property Area')
#
# TypeError: 'DataFrame' object is not callable

# %%
cross_tab = pd.crosstab(loan_df['Property_Area'], loan_df['Self_Employed'])
cross_tab.plot(kind='bar', stacked=True, figsize=(8,6), colormap='viridis')
plt.title('Self_employed by Property Area')
plt.xlabel('Property Area')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Self_employed')
plt.tight_layout()
plt.show()

# %%
cross_tab = pd.crosstab(loan_df['Education'], loan_df['Gender'])
cross_tab.plot(kind='bar', stacked=True, figsize=(8,6), colormap='viridis')
plt.title('Education by Gender')
plt.xlabel(' Education')
plt.ylabel('Count')
plt.xticks(rotation=80)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>
# Self_employed by Property Area
#
# Education vs Gender
# </h3>

# %%
loan_df.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes           0      Graduate            No             5720
# 1   Male     Yes           1      Graduate            No             3076
# 2   Male     Yes           2      Graduate            No             5000
# 4   Male      No           0  Not Graduate            No             3276
# 5   Male     Yes           0  Not Graduate           Yes             2165
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# 1               1500       126.0             360.0             1.0
# 2               1800       208.0             360.0             1.0
# 4                  0        78.0             360.0             1.0
# 5               3422       152.0             360.0             1.0
#
#   Property_Area
# 0         Urban
# 1         Urban
# 2         Urban
# 4         Urban
# 5         Urban

# %% [markdown]
# <h2>Task 4: Geospatial Analysis (Optional) </h2>

# %%
fig = px.choropleth(data_frame=loan_df,locations='Property_Area',locationmode='Education',
              projection='orthographic',color='loan Approvel area')
fig.update_layout(template='plotly_dark')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 fig = px.choropleth(data_frame=loan_df,locations='Property_Area',locationmode='Education',
#       2               projection='orthographic',color='loan Approvel area')
#       3 fig.update_layout(template='plotly_dark')
#       4 fig.show()
#
# NameError: name 'px' is not defined

# %%
# distribution of sales data

fig, axes = plt.subplots(2,3, figsize=(15,10))
color = []
n = 0
for i in range (2):
    for j in range (3):
        if n>4:
            break
        sns.boxenplot(loan_df[num_column[n]], fill=True, ax=axes[i,j])
        axes[i,j].set_title(f"{nume_column[n]}")
        n+=1
plt.show()

# %%
top_10 = loan_df.sort_values(by='LoanAmount',ascending=False).head(10)
top_10

# %%
num_column = ('ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term')

# %%
plt.figure(figsize=(8,5))
plt.hist(loan_df['CoapplicantIncome'],bins=20)
plt.show()

# %% [markdown]
# <h3>Boxplots</h3>

# %%
sns.boxplot(x=loan_df['Property_Area'],y=loan_df['ApplicantIncome'])
plt.show()

# %% [markdown]
# <h2> Scatter plot</h2>

# %%
plt.scatter(loan_df["CoapplicantIncome"],loan_df["LoanAmount"], alpha= 0.5,color='green',marker='*')
plt.xlabel("Applicant Income")
plt.ylabel("LoanAmount")
plt.title("ApplicantIncome vs LoanAmount")
plt.show()

# %%
#matrix_df = loan_df['LoanAmount','Loan_Amount_Term'][10::]

# %% [markdown]
# <h3> Pairplot</h3>

# %%
sns.pairplot(loan_df)
plt.show()

# %%
sns.boxplot(x=loan_df['Property_Area'],y=loan_df['ApplicantIncome'])
plt.show()

# %% [markdown]
# <h3> boxplot</h3>

# %%
sns.violinplot(x=loan_df['Property_Area'],y=loan_df['ApplicantIncome'])
plt.show()

# %% [markdown]
# <h3> </h3>
